# %% [markdown]
# # %% [markdown]
# # # Análisis Básico de Trayectorias de Collatz
# # ## Santiago Alexis Villalba
# #
# # Este notebook muestra un análisis básico de trayectorias de Collatz
#
# # %%
# import sys
# sys.path.append('../src')  # Para importar módulos locales
#
# import numpy as np
# import matplotlib.pyplot as plt
# from simulations.collatz_simulations import collatz_sequence, classify_region
#
# # %%
# # Ejemplo con n=27
# n = 27
# seq = collatz_sequence(n)
# regions = classify_region(seq)
#
# print(f"Secuencia para n={n}:")
# print(seq)
# print("\nRegiones clasificadas:")
# print(regions)
#
# # %%
# # Visualización básica
# plt.figure(figsize=(10, 6))
# plt.plot(seq, 'o-')
# plt.xlabel('Paso')
# plt.ylabel('Valor')
# plt.title(f'Trayectoria de Collatz para n={n}')
# plt.grid(True)
# plt.savefig('../paper/figures/basic_trajectory_27.png', dpi=150)
# plt.show()
#
# # %%
# # Análisis de regiones ABC
# abc_counts = {'A': 0, 'B': 0, 'C': 0, 'D': 0}
# for r in regions:
#     abc_counts[r] += 1
#
# plt.figure(figsize=(8, 6))
# plt.bar(abc_counts.keys(), abc_counts.values())
# plt.title('Distribución de Regiones ABC')
# plt.ylabel('Conteo')
# plt.savefig('../paper/figures/region_distribution.png', dpi=150)
# plt.show()

# %%
# %% [markdown]
# # Análisis Básico de Trayectorias de Collatz
# ## Santiago Alexis Villalba
# 
# Este notebook muestra un análisis básico de trayectorias de Collatz

# %%
import sys
sys.path.append('../src')  # Para importar módulos locales

import numpy as np
import matplotlib.pyplot as plt
from simulations.collatz_simulations import collatz_sequence, classify_region

# %%
# Ejemplo con n=27
n = 27
seq = collatz_sequence(n)
regions = classify_region(seq)

print(f"Secuencia para n={n}:")
print(seq)
print("\nRegiones clasificadas:")
print(regions)

# %%
# Visualización básica
plt.figure(figsize=(10, 6))
plt.plot(seq, 'o-')
plt.xlabel('Paso')
plt.ylabel('Valor')
plt.title(f'Trayectoria de Collatz para n={n}')
plt.grid(True)
plt.savefig('../paper/figures/basic_trajectory_27.png', dpi=150)
plt.show()

# %%
# Análisis de regiones ABC
abc_counts = {'A': 0, 'B': 0, 'C': 0, 'D': 0}
for r in regions:
    abc_counts[r] += 1

plt.figure(figsize=(8, 6))
plt.bar(abc_counts.keys(), abc_counts.values())
plt.title('Distribución de Regiones ABC')
plt.ylabel('Conteo')
plt.savefig('../paper/figures/region_distribution.png', dpi=150)
plt.show()

# %%
# %% [markdown]
# # Análisis Básico de Trayectorias de Collatz
# ## Santiago Alexis Villalba
# 
# Este notebook muestra un análisis básico de trayectorias de Collatz

# %%
import sys
sys.path.append('../src')  # Para importar módulos locales

import numpy as np
import matplotlib.pyplot as plt
from simulations.collatz_simulations import collatz_sequence, classify_region

# %%
# Ejemplo con n=27
n = 27
seq = collatz_sequence(n)
regions = classify_region(seq)

print(f"Secuencia para n={n}:")
print(seq)
print("\nRegiones clasificadas:")
print(regions)

# %%
# Visualización básica
plt.figure(figsize=(10, 6))
plt.plot(seq, 'o-')
plt.xlabel('Paso')
plt.ylabel('Valor')
plt.title(f'Trayectoria de Collatz para n={n}')
plt.grid(True)
plt.savefig('../paper/figures/basic_trajectory_27.png', dpi=150)
plt.show()

# %%
# Análisis de regiones ABC
abc_counts = {'A': 0, 'B': 0, 'C': 0, 'D': 0}
for r in regions:
    abc_counts[r] += 1

plt.figure(figsize=(8, 6))
plt.bar(abc_counts.keys(), abc_counts.values())
plt.title('Distribución de Regiones ABC')
plt.ylabel('Conteo')
plt.savefig('../paper/figures/region_distribution.png', dpi=150)
plt.show()
